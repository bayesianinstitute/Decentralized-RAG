# %%
import os
import ipfshttpclient

# Connect to the IPFS client
client = ipfshttpclient.connect('/ip4/127.0.0.1/tcp/5001/http')

# Define the directory path
directory_path = "./qdrant_data/collections/test3"

# Check if the directory exists
if os.path.isdir(directory_path):
    # Upload the directory to IPFS
    result = client.add(directory_path, recursive=True,follow_symlinks=True )
    print("Upload result:", result)
else:
    print(f"Directory '{directory_path}' does not exist.")
# Out:
# Upload result: [<ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/config.json', 'Hash': 'QmPYwmjhmCY5RXxvDdLL7wKMF9NttnUXbgFevAsNcfv4ZN', 'Size': '589'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/version.info', 'Hash': 'QmYBjmQU8tP4V9BdDnVyA7UQ5ZwWVcVamCYRuoDTb2rSgW', 'Size': '13'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/newest_clocks.json', 'Hash': 'QmPnLYkD2XykP9eSnWFwYikToptWHqX59ATTKZCvhWz8FW', 'Size': '107'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/replica_state.json', 'Hash': 'Qmb3WLFVGzFgJm9SvueDS5428YNAGmDFvsEXrkzBsEvB7A', 'Size': '95'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/shard_config.json', 'Hash': 'QmafHrxptCcJ17ArMhoQbDTXQco8LbWGS1ZgXCBMW95to4', 'Size': '29'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/000004.log', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/CURRENT', 'Hash': 'QmZubNxw6cJcQa71G25nmQWL5WxFWUy5aDaqYtpmbyMhE4', 'Size': '24'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/IDENTITY', 'Hash': 'QmQMhuMGCCF4D4SYDQo3gVvJWTnnDp9wSEa2vJyWXXvsiJ', 'Size': '44'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/LOCK', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/LOG', 'Hash': 'QmPjzACKiVjAzw2ZCvm3cPhuWHbbHTgvtfxdN3zZuuxT7M', 'Size': '55161'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/MANIFEST-000005', 'Hash': 'QmS7RRsiba8158anccBuq7kyFAWqvQwyBU1VuWaq3wPX4A', 'Size': '312'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/OPTIONS-000007', 'Hash': 'QmVKRa2hoRP6vK7epJVDcY9zkcU2WMeWVs85uDm3oKPMot', 'Size': '25354'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/segment.json', 'Hash': 'QmaWMsLxgHtNgE1RXbEjwdiLSKRbF7yHHq4UpPxQhfigE8', 'Size': '221'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/version.info', 'Hash': 'QmbkYvobvYcvKf5emeG7qBhyhz7huoRk2hHbRqigixfeWj', 'Size': '13'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/000004.log', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/config.json', 'Hash': 'Qmd6on3PQeHB3wwS8yUaNoaTps5Wymi1cRhdjLDUCwpBGz', 'Size': '29'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/CURRENT', 'Hash': 'QmZubNxw6cJcQa71G25nmQWL5WxFWUy5aDaqYtpmbyMhE4', 'Size': '24'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/IDENTITY', 'Hash': 'QmQMTPiLGwiVX4pbgfQFvkYXaDuvGiUBPk5awwcAb5qnnq', 'Size': '44'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/LOCK', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/LOG', 'Hash': 'QmU4HRQpNbnDoDX2TqqSuBvozTMLvL8VTyqgrwnC6VZJKe', 'Size': '17793'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/MANIFEST-000005', 'Hash': 'QmciAA6YcThKAWEB7DW4cNhQ2XFCV3H2YitbvgUYevPQBP', 'Size': '78'}>, <ipfshttpclient.client.base.ResponseBase: {'Name' ...

# %%
import os
import ipfshttpclient
from loguru import logger

class IPFSManager:
    def __init__(self, ipfs_address='/ip4/127.0.0.1/tcp/5001/http'):
        # Set up logging
        # Connect to the IPFS client
        self.client = ipfshttpclient.connect(ipfs_address)
    
    def upload_directory(self, directory_path, recursive=True, follow_symlinks=True):
        if os.path.isdir(directory_path):
            logger.info(f"Uploading directory: {directory_path}")
            try:
                # Upload the directory to IPFS
                result = self.client.add(directory_path, recursive=recursive, follow_symlinks=follow_symlinks)
                logger.info(f"Upload result: {result}")
                return result
            except Exception as e:
                logger.error(f"Failed to upload directory '{directory_path}': {e}")
                return None
        else:
            logger.warning(f"Directory {directory_path} does not exist.")
            return None

    def download_files(self, upload_result, base_directory):
        os.makedirs(base_directory, exist_ok=True)
        logger.info(f"Starting download to base directory: {base_directory}")

        for file_info in upload_result:
            file_name = file_info['Name']
            file_hash = file_info['Hash']
            
            # Create directory structure if necessary
            file_path = os.path.join(base_directory, file_name)
            os.makedirs(os.path.dirname(file_path), exist_ok=True)
            
            try:
                # Download the file content from IPFS
                file_content = self.client.cat(file_hash)
                
                # Save the content to the file
                with open(file_path, 'wb') as file:
                    file.write(file_content)
                
                logger.info(f"Downloaded and saved file: {file_path}")
            except Exception as e:
                logger.error(f"Failed to download file with hash '{file_hash}': {e}")

# Usage example:
if __name__ == "__main__":
    # Create an IPFSManager instance
    ipfs_manager = IPFSManager()

    # Upload directory
    upload_result = ipfs_manager.upload_directory("./qdrant_data/collections/test3")

    # Define the base directory where you want to save the downloaded files
    base_directory = "./downloaded_files"

    # Example upload result with names and hashes
    if upload_result:
        # Download files
        ipfs_manager.download_files(upload_result, base_directory)
    else:
        logger.info("No uploaded result.")
# Out:
# 2024-09-06 00:03:22.175 | INFO     | __main__:upload_directory:13 - Uploading directory: ./qdrant_data/collections/test3
# 2024-09-06 00:03:22.404 | INFO     | __main__:upload_directory:17 - Upload result: [<ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/config.json', 'Hash': 'QmPYwmjhmCY5RXxvDdLL7wKMF9NttnUXbgFevAsNcfv4ZN', 'Size': '589'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/version.info', 'Hash': 'QmYBjmQU8tP4V9BdDnVyA7UQ5ZwWVcVamCYRuoDTb2rSgW', 'Size': '13'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/newest_clocks.json', 'Hash': 'QmPnLYkD2XykP9eSnWFwYikToptWHqX59ATTKZCvhWz8FW', 'Size': '107'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/replica_state.json', 'Hash': 'Qmb3WLFVGzFgJm9SvueDS5428YNAGmDFvsEXrkzBsEvB7A', 'Size': '95'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/shard_config.json', 'Hash': 'QmafHrxptCcJ17ArMhoQbDTXQco8LbWGS1ZgXCBMW95to4', 'Size': '29'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/000004.log', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/CURRENT', 'Hash': 'QmZubNxw6cJcQa71G25nmQWL5WxFWUy5aDaqYtpmbyMhE4', 'Size': '24'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/IDENTITY', 'Hash': 'QmQMhuMGCCF4D4SYDQo3gVvJWTnnDp9wSEa2vJyWXXvsiJ', 'Size': '44'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/LOCK', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/LOG', 'Hash': 'QmPjzACKiVjAzw2ZCvm3cPhuWHbbHTgvtfxdN3zZuuxT7M', 'Size': '55161'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/MANIFEST-000005', 'Hash': 'QmS7RRsiba8158anccBuq7kyFAWqvQwyBU1VuWaq3wPX4A', 'Size': '312'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/OPTIONS-000007', 'Hash': 'QmVKRa2hoRP6vK7epJVDcY9zkcU2WMeWVs85uDm3oKPMot', 'Size': '25354'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/segment.json', 'Hash': 'QmaWMsLxgHtNgE1RXbEjwdiLSKRbF7yHHq4UpPxQhfigE8', 'Size': '221'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/version.info', 'Hash': 'QmbkYvobvYcvKf5emeG7qBhyhz7huoRk2hHbRqigixfeWj', 'Size': '13'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/000004.log', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/config.json', 'Hash': 'Qmd6on3PQeHB3wwS8yUaNoaTps5Wymi1cRhdjLDUCwpBGz', 'Size': '29'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/CURRENT', 'Hash': 'QmZubNxw6cJcQa71G25nmQWL5WxFWUy5aDaqYtpmbyMhE4', 'Size': '24'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/IDENTITY', 'Hash': 'QmQMTPiLGwiVX4pbgfQFvkYXaDuvGiUBPk5awwcAb5qnnq', 'Size': '44'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/LOCK', 'Hash': 'QmbFMke1KXqnYyBBWxB74N4c5SBnJMVAiMNRcGu6x1AwQH', 'Size': '6'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/LOG', 'Hash': 'QmU4HRQpNbnDoDX2TqqSuBvozTMLvL8VTyqgrwnC6VZJKe', 'Size': '17793'}>, <ipfshttpclient.client.base.ResponseBase: {'Name': 'test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/MANIFEST-000005', 'Hash': 'QmciAA6YcThKAWEB7DW4cNhQ2XFCV3H2YitbvgUYevPQBP ...
# 2024-09-06 00:03:22.405 | INFO     | __main__:download_files:28 - Starting download to base directory: ./downloaded_files
# 2024-09-06 00:03:22.423 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/config.json
# 2024-09-06 00:03:22.440 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/version.info
# 2024-09-06 00:03:22.445 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/newest_clocks.json
# 2024-09-06 00:03:22.449 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/replica_state.json
# 2024-09-06 00:03:22.471 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/shard_config.json
# 2024-09-06 00:03:22.487 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/000004.log
# 2024-09-06 00:03:22.502 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/CURRENT
# 2024-09-06 00:03:22.518 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/IDENTITY
# 2024-09-06 00:03:22.532 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/LOCK
# 2024-09-06 00:03:22.536 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/LOG
# 2024-09-06 00:03:22.540 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/MANIFEST-000005
# 2024-09-06 00:03:22.543 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/OPTIONS-000007
# 2024-09-06 00:03:22.547 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/segment.json
# 2024-09-06 00:03:22.564 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/version.info
# 2024-09-06 00:03:22.579 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/000004.log
# 2024-09-06 00:03:22.583 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/config.json
# 2024-09-06 00:03:22.610 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/CURRENT
# 2024-09-06 00:03:22.625 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/IDENTITY
# 2024-09-06 00:03:22.629 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/LOCK
# 2024-09-06 00:03:22.657 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/LOG
# 2024-09-06 00:03:22.661 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/MANIFEST-000005
# 2024-09-06 00:03:22.687 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/0c6c0a72-9e58-4845-861f-f99518fa5e1d/payload_index/OPTIONS-000007
# 2024-09-06 00:03:22.703 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/000004.log
# 2024-09-06 00:03:22.707 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/CURRENT
# 2024-09-06 00:03:22.734 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/IDENTITY
# 2024-09-06 00:03:22.737 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/LOCK
# 2024-09-06 00:03:22.765 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/LOG
# 2024-09-06 00:03:22.769 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/MANIFEST-000005
# 2024-09-06 00:03:22.796 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/OPTIONS-000007
# 2024-09-06 00:03:22.811 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/segment.json
# 2024-09-06 00:03:22.826 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/version.info
# 2024-09-06 00:03:22.829 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/000004.log
# 2024-09-06 00:03:22.832 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/config.json
# 2024-09-06 00:03:22.857 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/CURRENT
# 2024-09-06 00:03:22.872 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/IDENTITY
# 2024-09-06 00:03:22.888 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/LOCK
# 2024-09-06 00:03:22.891 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/LOG
# 2024-09-06 00:03:22.919 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/MANIFEST-000005
# 2024-09-06 00:03:22.923 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/49ed39f6-bd41-43d4-abd7-d4d9bc955b18/payload_index/OPTIONS-000007
# 2024-09-06 00:03:22.926 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/000008.log
# 2024-09-06 00:03:22.949 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/000009.sst
# 2024-09-06 00:03:22.965 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/000010.sst
# 2024-09-06 00:03:22.980 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/000011.sst
# 2024-09-06 00:03:22.997 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/000012.sst
# 2024-09-06 00:03:23.000 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/CURRENT
# 2024-09-06 00:03:23.027 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/IDENTITY
# 2024-09-06 00:03:23.042 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/LOCK
# 2024-09-06 00:03:23.046 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/LOG
# 2024-09-06 00:03:23.078 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/MANIFEST-000005
# 2024-09-06 00:03:23.105 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/OPTIONS-000007
# 2024-09-06 00:03:23.108 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/segment.json
# 2024-09-06 00:03:23.136 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/version.info
# 2024-09-06 00:03:23.140 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/000004.log
# 2024-09-06 00:03:23.168 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/config.json
# 2024-09-06 00:03:23.183 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/CURRENT
# 2024-09-06 00:03:23.198 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/IDENTITY
# 2024-09-06 00:03:23.204 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/LOCK
# 2024-09-06 00:03:23.209 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/LOG
# 2024-09-06 00:03:23.216 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/MANIFEST-000005
# 2024-09-06 00:03:23.244 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/5021a110-10df-4a32-9a76-49a7f7d06152/payload_index/OPTIONS-000007
# 2024-09-06 00:03:23.259 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/000004.log
# 2024-09-06 00:03:23.263 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/CURRENT
# 2024-09-06 00:03:23.290 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/IDENTITY
# 2024-09-06 00:03:23.306 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/LOCK
# 2024-09-06 00:03:23.310 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/LOG
# 2024-09-06 00:03:23.338 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/MANIFEST-000005
# 2024-09-06 00:03:23.343 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/OPTIONS-000007
# 2024-09-06 00:03:23.367 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/segment.json
# 2024-09-06 00:03:23.382 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/version.info
# 2024-09-06 00:03:23.398 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/000004.log
# 2024-09-06 00:03:23.414 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/config.json
# 2024-09-06 00:03:23.430 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/CURRENT
# 2024-09-06 00:03:23.434 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/IDENTITY
# 2024-09-06 00:03:23.460 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/LOCK
# 2024-09-06 00:03:23.476 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/LOG
# 2024-09-06 00:03:23.481 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/MANIFEST-000005
# 2024-09-06 00:03:23.485 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7033405c-cc1c-47ca-895d-03ccec51ecc8/payload_index/OPTIONS-000007
# 2024-09-06 00:03:23.505 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/000004.log
# 2024-09-06 00:03:23.509 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/CURRENT
# 2024-09-06 00:03:23.536 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/IDENTITY
# 2024-09-06 00:03:23.552 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/LOCK
# 2024-09-06 00:03:23.569 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/LOG
# 2024-09-06 00:03:23.573 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/MANIFEST-000005
# 2024-09-06 00:03:23.576 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/OPTIONS-000007
# 2024-09-06 00:03:23.579 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/segment.json
# 2024-09-06 00:03:23.584 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/version.info
# 2024-09-06 00:03:23.598 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/000004.log
# 2024-09-06 00:03:23.601 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/config.json
# 2024-09-06 00:03:23.630 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/CURRENT
# 2024-09-06 00:03:23.645 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/IDENTITY
# 2024-09-06 00:03:23.659 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/LOCK
# 2024-09-06 00:03:23.675 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/LOG
# 2024-09-06 00:03:23.690 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/MANIFEST-000005
# 2024-09-06 00:03:23.706 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/7c773730-88f1-4d7b-9873-dff149ed4614/payload_index/OPTIONS-000007
# 2024-09-06 00:03:23.721 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/000004.log
# 2024-09-06 00:03:23.737 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/CURRENT
# 2024-09-06 00:03:23.752 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/IDENTITY
# 2024-09-06 00:03:23.756 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/LOCK
# 2024-09-06 00:03:23.784 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/LOG
# 2024-09-06 00:03:23.798 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/MANIFEST-000005
# 2024-09-06 00:03:23.814 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/OPTIONS-000007
# 2024-09-06 00:03:23.818 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/segment.json
# 2024-09-06 00:03:23.822 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/version.info
# 2024-09-06 00:03:23.826 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/000004.log
# 2024-09-06 00:03:23.829 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/config.json
# 2024-09-06 00:03:23.845 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/CURRENT
# 2024-09-06 00:03:23.859 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/IDENTITY
# 2024-09-06 00:03:23.874 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/LOCK
# 2024-09-06 00:03:23.890 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/LOG
# 2024-09-06 00:03:23.906 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/MANIFEST-000005
# 2024-09-06 00:03:23.921 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/8e6c3897-da0d-424a-bb34-088f401f05bb/payload_index/OPTIONS-000007
# 2024-09-06 00:03:23.925 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/000004.log
# 2024-09-06 00:03:23.952 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/CURRENT
# 2024-09-06 00:03:23.956 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/IDENTITY
# 2024-09-06 00:03:23.983 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/LOCK
# 2024-09-06 00:03:23.999 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/LOG
# 2024-09-06 00:03:24.014 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/MANIFEST-000005
# 2024-09-06 00:03:24.029 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/OPTIONS-000007
# 2024-09-06 00:03:24.045 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/segment.json
# 2024-09-06 00:03:24.050 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/version.info
# 2024-09-06 00:03:24.075 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/000004.log
# 2024-09-06 00:03:24.090 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/config.json
# 2024-09-06 00:03:24.093 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/CURRENT
# 2024-09-06 00:03:24.121 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/IDENTITY
# 2024-09-06 00:03:24.137 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/LOCK
# 2024-09-06 00:03:24.154 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/LOG
# 2024-09-06 00:03:24.157 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/MANIFEST-000005
# 2024-09-06 00:03:24.162 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/eeb8ea14-389e-4211-9f68-9b134a62bfa5/payload_index/OPTIONS-000007
# 2024-09-06 00:03:24.166 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/000008.log
# 2024-09-06 00:03:24.185 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/000009.sst
# 2024-09-06 00:03:24.191 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/000010.sst
# 2024-09-06 00:03:24.195 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/000011.sst
# 2024-09-06 00:03:24.205 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/000012.sst
# 2024-09-06 00:03:24.231 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/CURRENT
# 2024-09-06 00:03:24.234 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/IDENTITY
# 2024-09-06 00:03:24.261 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/LOCK
# 2024-09-06 00:03:24.277 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/LOG
# 2024-09-06 00:03:24.293 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/MANIFEST-000005
# 2024-09-06 00:03:24.308 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/OPTIONS-000007
# 2024-09-06 00:03:24.323 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/segment.json
# 2024-09-06 00:03:24.327 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/version.info
# 2024-09-06 00:03:24.354 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/000004.log
# 2024-09-06 00:03:24.359 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/config.json
# 2024-09-06 00:03:24.385 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/CURRENT
# 2024-09-06 00:03:24.400 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/IDENTITY
# 2024-09-06 00:03:24.416 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/LOCK
# 2024-09-06 00:03:24.432 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/LOG
# 2024-09-06 00:03:24.435 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/MANIFEST-000005
# 2024-09-06 00:03:24.462 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/segments/f9534184-7e16-443b-9680-793f0940764b/payload_index/OPTIONS-000007
# 2024-09-06 00:03:24.477 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/wal/first-index
# 2024-09-06 00:03:24.641 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/wal/open-1
# 2024-09-06 00:03:24.802 | INFO     | __main__:download_files:46 - Downloaded and saved file: ./downloaded_files\test3/0/wal/open-2
# 2024-09-06 00:03:24.818 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmSnmkZThTesANCXdSqJseshz7B9FyJgvVyVmcvKhLLVfA': this dag node is a directory
# 2024-09-06 00:03:24.833 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmUyqPKmNmBtGoeTWdkJDvxX3HTbzSDeNABfqQwHQJW2k3': this dag node is a directory
# 2024-09-06 00:03:24.836 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmQWq2jLbgmhhTptc8z2G3SzQhjQiHjSgZ4AD5tfzrBDby': this dag node is a directory
# 2024-09-06 00:03:24.864 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmcA2RbTbD8gBrPibCVsPCN9ruEjMntDg36ddPGqfZwfkc': this dag node is a directory
# 2024-09-06 00:03:24.879 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmYXMCaPWWb74P3pyrH6LpQmzJpM4bQM5CATwMGxcy2mKX': this dag node is a directory
# 2024-09-06 00:03:24.894 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmRJP38kzJFdwApT9U5HJxaB45RzueCdnShdDiBmmxNLTz': this dag node is a directory
# 2024-09-06 00:03:24.909 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmPMQtUun2LaYjZGLgzJJcC9TGtcbVtbFiwYJ2LeBezbvD': this dag node is a directory
# 2024-09-06 00:03:24.924 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmbUr6z36TEpGfHn16YBGE3uaLSLYpCzDvmpzEKLipr3yv': this dag node is a directory
# 2024-09-06 00:03:24.940 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmNTuPvUFQityoHeZfcBeCeTuhnnnaTcXN5Py6GXNqntfk': this dag node is a directory
# 2024-09-06 00:03:24.954 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmYuku9dCqufbuqnqWkLQYkhE2i1N44hctrXjNWpZta3f9': this dag node is a directory
# 2024-09-06 00:03:24.958 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmVWnENSuF3W9WbVGHq6bVk6FmbFmAr4K8x12pWt5J6T7n': this dag node is a directory
# 2024-09-06 00:03:24.985 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmNsn7HG9WCizCEKDMa7KBy4Hz3C2dT3fMPnKutrkwtL2p': this dag node is a directory
# 2024-09-06 00:03:24.988 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmdSRZUvgiNdxGLz4GNoGoWttVWFe3phnxNt3nRoJjfZxa': this dag node is a directory
# 2024-09-06 00:03:24.991 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmUzTEYrxRrNAjh1GEPQ1YaogVBfKNTraegMRyNUg5ZKoc': this dag node is a directory
# 2024-09-06 00:03:25.015 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'Qmav3j2g4p2r2RihXodVKAVfuS5PyjsDkRUV2DXNibrKL1': this dag node is a directory
# 2024-09-06 00:03:25.019 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmPG66tz3do48D8srDGynoqEYULkuiBk1AVo49zvJTGzD3': this dag node is a directory
# 2024-09-06 00:03:25.045 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmTcCLmvx7WL44ATJrvT4FjP1KMom3NcP8R99BSCs4fAKJ': this dag node is a directory
# 2024-09-06 00:03:25.049 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmY4YapywXqgazNBdknm7WnXYjkCNnPeDo2eJiZCgeW6Df': this dag node is a directory
# 2024-09-06 00:03:25.062 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmdJGzHprAzeeZUZvEZ5gp5kZ7zCqVgwbrAJCs9MVkiFjD': this dag node is a directory
# 2024-09-06 00:03:25.077 | ERROR    | __main__:download_files:48 - Failed to download file with hash 'QmTXLZ3pN9qFaJxKqkiZotjmeFr73Yca4Th6ua9SX47zBc': this dag node is a directory

# %%
import os
import zipfile
import ipfshttpclient
from loguru import logger

class IPFSManager:
    def __init__(self, ipfs_address='/ip4/127.0.0.1/tcp/5001/http'):
        # Set up logging
        # Connect to the IPFS client
        self.client = ipfshttpclient.connect(ipfs_address)
    
    def zip_directory(self, directory_path, zip_file_path):
        logger.info(f"Creating zip file at: {zip_file_path}")

        with zipfile.ZipFile(zip_file_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, dirs, files in os.walk(directory_path):
                for file in files:
                    file_path = os.path.join(root, file)
                    zipf.write(file_path, os.path.relpath(file_path, directory_path))
        
        logger.info(f"Zip file created successfully: {zip_file_path}")
        return zip_file_path

    def upload_file(self, file_path):
        if os.path.isfile(file_path):
            logger.info(f"Uploading file: {file_path}")
            try:
                # Upload the file to IPFS
                result = self.client.add(file_path)
                logger.info(f"Upload result: {result}")
                return result
            except Exception as e:
                logger.error(f"Failed to upload file '{file_path}': {e}")
                return None
        else:
            logger.warning(f"File {file_path} does not exist.")
            return None

    def download_file(self, file_hash, download_path):
        logger.info(f"Starting download to: {download_path}")

        os.makedirs(os.path.dirname(download_path), exist_ok=True)
        
        try:
            # Download the file content from IPFS
            file_content = self.client.cat(file_hash)
            
            # Save the content to the file
            with open(download_path, 'wb') as file:
                file.write(file_content)
            
            logger.info(f"Downloaded and saved file: {download_path}")
        except Exception as e:
            logger.error(f"Failed to download file with hash '{file_hash}': {e}")

    def unzip_file(self, zip_file_path, extract_to_path):
        logger.info(f"Unzipping file: {zip_file_path} to {extract_to_path}")

        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to_path)
        
        logger.info(f"Unzipped file successfully to: {extract_to_path}")

# Usage example:
if __name__ == "__main__":
    # Create an IPFSManager instance
    ipfs_manager = IPFSManager()

    # Define paths
    directory_path = "./qdrant_data/collections/test3"
    zip_file_path = "./qdrant_data_backup.zip"

    # Zip directory
    zip_file = ipfs_manager.zip_directory(directory_path, zip_file_path)

    # Upload the zip file
    upload_result = ipfs_manager.upload_file(zip_file)

    # Define paths for download and extraction
    download_path = "./zipdownloaded_files/qdrant_data_backup.zip"
    extract_to_path = "./qdrant_data/collections/global_data"

    # Example upload result with file hash
    if upload_result:
        # Download the zip file
        file_hash = upload_result['Hash']
        ipfs_manager.download_file(file_hash, download_path)

        # Unzip the downloaded file
        ipfs_manager.unzip_file(download_path, extract_to_path)
    else:
        logger.info("No uploaded result.")
# Out:
# 2024-09-06 01:09:58.907 | INFO     | __main__:zip_directory:13 - Creating zip file at: ./qdrant_data_backup.zip
# 2024-09-06 01:09:59.309 | INFO     | __main__:zip_directory:21 - Zip file created successfully: ./qdrant_data_backup.zip
# 2024-09-06 01:09:59.310 | INFO     | __main__:upload_file:26 - Uploading file: ./qdrant_data_backup.zip
# 2024-09-06 01:09:59.327 | INFO     | __main__:upload_file:30 - Upload result: <ipfshttpclient.client.base.ResponseBase: {'Name': 'qdrant_data_backup.zip', 'Hash': 'QmbjvpLLhRkBc7xr4iwdJSW28tzkSgMv1S8Me9ttvHiWX3', 'Size': '246582'}>
# 2024-09-06 01:09:59.328 | INFO     | __main__:download_file:40 - Starting download to: ./zipdownloaded_files/qdrant_data_backup.zip
# 2024-09-06 01:09:59.356 | INFO     | __main__:download_file:52 - Downloaded and saved file: ./zipdownloaded_files/qdrant_data_backup.zip
# 2024-09-06 01:09:59.356 | INFO     | __main__:unzip_file:57 - Unzipping file: ./zipdownloaded_files/qdrant_data_backup.zip to ./qdrant_data/collections/global_data
# 2024-09-06 01:09:59.562 | INFO     | __main__:unzip_file:62 - Unzipped file successfully to: ./qdrant_data/collections/global_data

# %%
from bayesrag.vector_db import VectorDB

db=VectorDB(collection_name="test3")


db.create_db()

from langchain.schema import Document

# Create a list of Document objects
chunks = [
    Document(page_content="This is the first text chunk", metadata={"source": "doc1"}),
    Document(page_content="This is the second text chunk", metadata={"source": "doc2"})
]

# Upsert embeddings into Qdrant
db.upsert_embeddings(chunks)
# Out:
# 2024-09-05 23:24:52.608 | INFO     | bayesrag.vector_db:create_db:18 - Vector DB successfully created: test3
# 2024-09-05 23:24:52.610 | INFO     | bayesrag.vector_db:upsert_embeddings:34 - Upserting embeddings into Vector DB...
# 2024-09-05 23:24:52.739 | INFO     | bayesrag.vector_db:upsert_embeddings:45 - Embeddings created successfully

# %%
! dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A48A-C644
#
#  Directory of c:\Users\faiza\Music\llmResearch\rag\research\communication
#
# 09/05/2024  11:26 PM    <DIR>          .
# 08/24/2024  06:56 PM    <DIR>          ..
# 09/05/2024  10:55 PM             6,888 ipfs.ipynb
# 08/07/2024  10:23 PM    <DIR>          kafka
# 08/07/2024  10:23 PM    <DIR>          mqtt
# 09/05/2024  11:26 PM    <DIR>          qdrant_storage
#                1 File(s)          6,888 bytes
#                5 Dir(s)  35,329,863,680 bytes free

# %%
! dir qdrant_storage
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A48A-C644
#
#  Directory of c:\Users\faiza\Music\llmResearch\rag\research\communication\qdrant_storage
#
# 09/05/2024  11:26 PM    <DIR>          .
# 09/05/2024  11:26 PM    <DIR>          ..
# 09/05/2024  11:26 PM    <DIR>          aliases
# 09/05/2024  11:26 PM    <DIR>          collections
# 09/05/2024  11:19 PM               324 raft_state.json
#                1 File(s)            324 bytes
#                4 Dir(s)  35,329,302,528 bytes free

# %%
import os
import shutil
import ipfshttpclient
from loguru import logger

class QdrantIPFSHandler:
    def __init__(self, ipfs_host='127.0.0.1', ipfs_port=5001, ipfs_connection_link=None):
        if ipfs_connection_link is None:
            ipfs_connection_link = f'/ip4/{ipfs_host}/tcp/{ipfs_port}/http'
        self.ipfs_client = self._connect_to_ipfs(ipfs_connection_link)

    def _connect_to_ipfs(self, connection_link):
        try:
            client = ipfshttpclient.connect(connection_link)
            logger.info("Connected to IPFS")
            return client
        except Exception as e:
            logger.error(f"Error during IPFS connection: {e}")
            raise

    def zip_folder(self, source_folder, zip_file_path):
        try:
            shutil.make_archive(zip_file_path, 'zip', source_folder)
            logger.info(f"Successfully zipped {source_folder} to {zip_file_path}.zip")
        except Exception as e:
            logger.error(f"Error zipping folder: {str(e)}")
            raise

    def upload_to_ipfs(self, file_path):
        try:
            file_hash = self.ipfs_client.add(file_path)['Hash']
            logger.info(f"File uploaded to IPFS with hash: {file_hash}")
            return file_hash
        except Exception as e:
            logger.error(f"Error uploading file to IPFS: {str(e)}")
            raise

    def handle_qdrant_data(self, source_folder, zip_file_path):
        self.zip_folder(source_folder, zip_file_path)
        ipfs_hash = self.upload_to_ipfs(f"{zip_file_path}.zip")
        return ipfs_hash

# Example usage:
if __name__ == "__main__":
    handler = QdrantIPFSHandler()
    
    qdrant_data_folder = './qdrant_data'
    zip_file_path = './qdrant_data_backup'
    
    ipfs_hash = handler.handle_qdrant_data(qdrant_data_folder, zip_file_path)
    
    if ipfs_hash:
        logger.info(f"Zipped Qdrant data uploaded to IPFS with hash: {ipfs_hash}")
    else:
        logger.error("Failed to upload zipped Qdrant data to IPFS.")
# Out:
# c:\Users\faiza\Music\llmResearch\rag\env\Lib\site-packages\ipfshttpclient\client\__init__.py:75: VersionMismatch: Unsupported daemon version '0.23.0' (not in range: 0.5.0 ≤ … < 0.9.0)
#   warnings.warn(exceptions.VersionMismatch(version, minimum, maximum))
# 2024-09-05 23:37:47.395 | INFO     | __main__:_connect_to_ipfs:15 - Connected to IPFS
# 2024-09-05 23:37:48.223 | INFO     | __main__:zip_folder:24 - Successfully zipped ./qdrant_data to ./qdrant_data_backup.zip
# 2024-09-05 23:37:48.293 | INFO     | __main__:upload_to_ipfs:32 - File uploaded to IPFS with hash: QmadmszDYPXFfZ87cjV9mhJgrtHMZzF9qgWirr9TrAPVqr
# 2024-09-05 23:37:48.294 | INFO     | __main__:<module>:53 - Zipped Qdrant data uploaded to IPFS with hash: QmadmszDYPXFfZ87cjV9mhJgrtHMZzF9qgWirr9TrAPVqr
